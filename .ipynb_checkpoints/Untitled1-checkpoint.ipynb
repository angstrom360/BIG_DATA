# %%
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import scipy as sp
import plotly.plotly as py
import plotly.graph_objs as go
import geocoder
import requests
from time import sleep
from bs4 import BeautifulSoup
import requests
import qgrid

# %%
#Importing data
crime = "Crimes_-_One_year_prior_to_present.csv"

c_df = pd.read_csv(crime, encoding="ISO-8859-1", dtype='unicode')
neighborhood = pd.read_csv("CHICAGO_Neighborhood.csv", encoding="ISO-8859-1", dtype='unicode')

# %%
crime = c_df.loc[c_df["WARD"] == "27"]

# %%
crime.columns
# Out:
# Index(['CASE#', 'DATE  OF OCCURRENCE', 'BLOCK', ' IUCR',
#        ' PRIMARY DESCRIPTION', ' SECONDARY DESCRIPTION',
#        ' LOCATION DESCRIPTION', 'ARREST', 'DOMESTIC', 'BEAT', 'WARD', 'FBI CD',
#        'X COORDINATE', 'Y COORDINATE', 'LATITUDE', 'LONGITUDE', 'LOCATION'],
#       dtype='object')

# %%
crime.groupby(["WARD"]).count().sort_values(by="CASE#", ascending = False)

# %%
pd.groupby(c_df['WARD'])
# Out:
# D:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
#
# pd.groupby() is deprecated and will be removed; Please use the Series.groupby() or DataFrame.groupby() methods
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-decb8f3d6fe5> in <module>()
# ----> 1 pd.groupby(c_df['WARD'])
#
# D:\Program Files\Anaconda3\lib\site-packages\pandas\core\api.py in groupby(*args, **kwargs)
#      66                   "DataFrame.groupby() methods",
#      67                   FutureWarning, stacklevel=2)
# ---> 68     return args[0].groupby(*args[1:], **kwargs)
#      69
#      70
#
# D:\Program Files\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6657
#    6658         if level is None and by is None:
# -> 6659             raise TypeError("You have to supply one of 'by' and 'level'")
#    6660         axis = self._get_axis_number(axis)
#    6661         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#
# TypeError: You have to supply one of 'by' and 'level'

# %%
c_df.groupby(["WARD"]).count().sort_values(by="DATE  OF OCCURRENCE",ascending = False)
# Out:
#       CASE#  DATE  OF OCCURRENCE  BLOCK   IUCR   PRIMARY DESCRIPTION  \
# WARD
# 42    18022                18022  18022  18022                 18022
# 24    12461                12461  12461  12461                 12461
# 28    11615                11615  11615  11615                 11615
# 27    10961                10961  10961  10961                 10961
# 2     10200                10200  10200  10200                 10200
# 17     8779                 8779   8779   8779                  8779
# 6      8665                 8665   8665   8665                  8665
# 21     8113                 8113   8113   8113                  8113
# 20     7425                 7425   7425   7425                  7425
# 9      7200                 7200   7200   7200                  7200
# 8      6905                 6905   6905   6905                  6905
# 3      6872                 6872   6872   6872                  6872
# 34     6793                 6793   6793   6793                  6793
# 7      6781                 6781   6781   6781                  6781
# 16     6620                 6620   6620   6620                  6620
# 37     6599                 6599   6599   6599                  6599
# 5      6262                 6262   6262   6262                  6262
# 15     5743                 5743   5743   5743                  5743
# 29     5555                 5555   5555   5555                  5555
# 4      5427                 5427   5427   5427                  5427
# 1      4742                 4742   4742   4742                  4742
# 43     4294                 4294   4294   4294                  4294
# 32     4192                 4192   4192   4192                  4192
